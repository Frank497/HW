# %% [markdown]
# <a href="https://colab.research.google.com/github/Frank497/NTHU_2023_DLBOI_HW/blob/main/hw2/report%20code/hw2_CE.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# <div align="center">
#
# # National Tsing Hua University
#
# ### Fall 2023
#
# #### 11210IPT 553000
#
# #### Deep Learning in Biomedical Optical Imaging
#
# ## Lab 3: Hyperparameter Tuning
#
# </div>

# %%
# # Download dataset
# !wget https://raw.githubusercontent.com/TacoXDD/homeworks/master/dataset/train/normal.npy
# !wget https://raw.githubusercontent.com/TacoXDD/homeworks/master/dataset/train/pneumonia.npy
# Out:
# --2023-10-15 15:53:26--  https://raw.githubusercontent.com/TacoXDD/homeworks/master/dataset/train/normal.npy
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 65536128 (62M) [application/octet-stream]
# Saving to: ‘normal.npy’
#
# normal.npy          100%[===================>]  62.50M   335MB/s    in 0.2s
#
# 2023-10-15 15:53:29 (335 MB/s) - ‘normal.npy’ saved [65536128/65536128]
#
# --2023-10-15 15:53:29--  https://raw.githubusercontent.com/TacoXDD/homeworks/master/dataset/train/pneumonia.npy
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 65536128 (62M) [application/octet-stream]
# Saving to: ‘pneumonia.npy’
#
# pneumonia.npy       100%[===================>]  62.50M   259MB/s    in 0.2s
#
# 2023-10-15 15:53:33 (259 MB/s) - ‘pneumonia.npy’ saved [65536128/65536128]

# %% [markdown]
# ## A. Data Loading and Preprocessing

# %%
import torch
from torch.utils.data import DataLoader, TensorDataset, random_split
import csv
import numpy as np

# Load Dataset
abnormal_scans = np.load('pneumonia.npy')
normal_scans = np.load('normal.npy')

print(f'Shape of abnormal_scans: {abnormal_scans.shape}')
print(f'Shape of normal_scans: {normal_scans.shape}')

# For the data having presence of pneumonia assign 1, for the normal ones assign 0.

abnormal_labels = np.ones((abnormal_scans.shape[0],))
normal_labels = np.zeros((normal_scans.shape[0],))

split_point = 800

x_train = np.concatenate((abnormal_scans[:split_point], normal_scans[:split_point]), axis=0)
y_train = np.concatenate((abnormal_labels[:split_point], normal_labels[:split_point]), axis=0)
x_val = np.concatenate((abnormal_scans[split_point:], normal_scans[split_point:]), axis=0)
y_val = np.concatenate((abnormal_labels[split_point:], normal_labels[split_point:]), axis=0)

# Convert to PyTorch tensors
x_train = torch.from_numpy(x_train).float()
y_train = torch.from_numpy(y_train).long()
x_val = torch.from_numpy(x_val).float()
y_val = torch.from_numpy(y_val).long()

# Create datasets
train_dataset = TensorDataset(x_train, y_train)
val_dataset = TensorDataset(x_val, y_val)

# Create dataloaders
train_loader = DataLoader(train_dataset, batch_size=32, shuffle=True)
val_loader = DataLoader(val_dataset, batch_size=32, shuffle=False)

print(f'Number of samples in train and validation are {len(train_loader.dataset)} and {len(val_loader.dataset)}.')
print(f'X_train: max value is {x_train.max().item()}, min value is {x_train.min().item()}, data type is {x_train.dtype}.')
# Out:
# Shape of abnormal_scans: (1000, 256, 256)
# Shape of normal_scans: (1000, 256, 256)
# Number of samples in train and validation are 1600 and 400.
# X_train: max value is 255.0, min value is 0.0, data type is torch.float32.

# %% [markdown]
# ## B. Defining Neural Networks in PyTorch

# %%
import torch.nn as nn
'''
# Model in Lab 2
model = nn.Sequential(
    nn.Flatten(),
    nn.Linear(256*256*1, 256),
    nn.ReLU(),
    nn.Dropout(0.72),
    nn.Linear(256, 2)
).cuda()
'''
# for BCE/CE compare
model = nn.Sequential(
    nn.Flatten(),

    nn.Linear(256*256*1, 64),
    nn.BatchNorm1d(64),
    nn.ReLU(),
    nn.Dropout(0.5),

    nn.Linear(64, 64),
    nn.BatchNorm1d(64),
    nn.ReLU(),
    nn.Dropout(0.5),

    nn.Linear(64, 64),
    nn.BatchNorm1d(64),
    nn.ReLU(),
    nn.Dropout(0.5),

    nn.Linear(64, 2),
    nn.Softmax()
).cuda()

print(model)
# Out:
# Sequential(
#   (0): Flatten(start_dim=1, end_dim=-1)
#   (1): Linear(in_features=65536, out_features=64, bias=True)
#   (2): BatchNorm1d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (3): ReLU()
#   (4): Dropout(p=0.5, inplace=False)
#   (5): Linear(in_features=64, out_features=64, bias=True)
#   (6): BatchNorm1d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (7): ReLU()
#   (8): Dropout(p=0.5, inplace=False)
#   (9): Linear(in_features=64, out_features=64, bias=True)
#   (10): BatchNorm1d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (11): ReLU()
#   (12): Dropout(p=0.5, inplace=False)
#   (13): Linear(in_features=64, out_features=2, bias=True)
#   (14): Softmax(dim=None)
# )

# %% [markdown]
# ## C. Training the Neural Network

# %%
import torch.optim as optim
from torch.optim.lr_scheduler import CosineAnnealingLR, StepLR

train_losses = []
val_losses = []
train_accuracies = []
val_accuracies = []

epochs = 90
best_val_loss = float('inf')

# Criterion and Optimizer
criterion = nn.CrossEntropyLoss()
optimizer = optim.Adam(model.parameters(), lr=1e-3)
lr_scheduler = CosineAnnealingLR(optimizer, T_max=len(train_loader)*epochs, eta_min=0)
# lr_scheduler = StepLR(optimizer, step_size=10, gamma=0.1)


with open('train outputs.csv', 'w') as f:
  # using csv.writer method from CSV package
  #write = csv.writer(f)

  for epoch in range(epochs):
      # Training
      model.train()
      total_loss = 0.0
      train_correct = 0
      total_train_samples = 0

      for images, labels in train_loader:
          images = images.cuda()
          images = images / 255.
          labels = labels.cuda()
          optimizer.zero_grad()
          outputs = model(images)
     # using csv.writer method from CSV package
#          write.writerow(outputs[:,0])
#          write.writerow(outputs[:,1])

          labels = labels.long()
          loss = criterion(outputs, labels)
          loss.backward()
          optimizer.step()
          total_loss += loss.item()

          train_predicted = outputs.argmax(-1)
          train_correct += (train_predicted.float() == labels).sum().item()
          total_train_samples += labels.size(0)
      #print(outputs[:,0])
      avg_train_loss = total_loss / len(train_loader)
      train_accuracy = 100. * train_correct / total_train_samples

      # Validation
      model.eval()
      total_val_loss = 0.0
      correct = 0
      total = 0
      with torch.no_grad():
          for images, labels in val_loader:
              images = images.cuda()
              images = images / 255.
              labels = labels.cuda()
              outputs = model(images)

              labels = labels.long()

              loss = criterion(outputs, labels)
              total_val_loss += loss.item()

              predicted = outputs.argmax(-1)
              correct += (predicted.float() == labels).sum().item()
              total += labels.size(0)

      avg_val_loss = total_val_loss / len(val_loader)
      val_accuracy = 100. * correct / total

      print(f'Epoch {epoch+1}/{epochs}, Train Loss: {avg_train_loss:.4f}, Train Accuracy: {train_accuracy:.2f}%, Val Loss: {avg_val_loss:.4f}, Val Accuracy: {val_accuracy:.2f}%')

      # Learning rate update
      lr_scheduler.step()

      # Checkpoint
      if avg_val_loss < best_val_loss:
          best_val_loss = avg_val_loss
          torch.save(model.state_dict(), 'model_classification.pth')

      # Store performance
      train_losses.append(avg_train_loss)
      train_accuracies.append(train_accuracy)
      val_losses.append(avg_val_loss)
      val_accuracies.append(val_accuracy)
# Out:
# /usr/local/lib/python3.10/dist-packages/torch/nn/modules/container.py:217: UserWarning: Implicit dimension choice for softmax has been deprecated. Change the call to include dim=X as an argument.
#   input = module(input)
# Epoch 1/90, Train Loss: 0.6216, Train Accuracy: 68.12%, Val Loss: 0.5333, Val Accuracy: 85.50%
# Epoch 2/90, Train Loss: 0.4936, Train Accuracy: 85.94%, Val Loss: 0.4509, Val Accuracy: 90.50%
# Epoch 3/90, Train Loss: 0.4318, Train Accuracy: 89.69%, Val Loss: 0.3964, Val Accuracy: 93.75%
# Epoch 4/90, Train Loss: 0.4033, Train Accuracy: 92.88%, Val Loss: 0.3962, Val Accuracy: 92.75%
# Epoch 5/90, Train Loss: 0.3833, Train Accuracy: 94.00%, Val Loss: 0.3807, Val Accuracy: 93.50%
# Epoch 6/90, Train Loss: 0.3727, Train Accuracy: 94.69%, Val Loss: 0.3766, Val Accuracy: 94.50%
# Epoch 7/90, Train Loss: 0.3787, Train Accuracy: 93.75%, Val Loss: 0.3769, Val Accuracy: 93.25%
# Epoch 8/90, Train Loss: 0.3669, Train Accuracy: 95.12%, Val Loss: 0.4062, Val Accuracy: 90.50%
# Epoch 9/90, Train Loss: 0.3597, Train Accuracy: 96.06%, Val Loss: 0.3615, Val Accuracy: 95.25%
# Epoch 10/90, Train Loss: 0.3626, Train Accuracy: 95.06%, Val Loss: 0.4033, Val Accuracy: 90.50%
# Epoch 11/90, Train Loss: 0.3691, Train Accuracy: 94.25%, Val Loss: 0.5965, Val Accuracy: 69.00%
# Epoch 12/90, Train Loss: 0.3617, Train Accuracy: 95.31%, Val Loss: 0.3679, Val Accuracy: 95.00%
# Epoch 13/90, Train Loss: 0.3639, Train Accuracy: 95.12%, Val Loss: 0.3707, Val Accuracy: 94.50%
# Epoch 14/90, Train Loss: 0.3518, Train Accuracy: 96.25%, Val Loss: 0.3603, Val Accuracy: 94.75%
# Epoch 15/90, Train Loss: 0.3497, Train Accuracy: 96.56%, Val Loss: 0.4228, Val Accuracy: 88.50%
# Epoch 16/90, Train Loss: 0.3580, Train Accuracy: 95.44%, Val Loss: 0.4575, Val Accuracy: 84.00%
# Epoch 17/90, Train Loss: 0.3582, Train Accuracy: 95.38%, Val Loss: 0.4455, Val Accuracy: 86.25%
# Epoch 18/90, Train Loss: 0.3555, Train Accuracy: 95.81%, Val Loss: 0.3684, Val Accuracy: 94.50%
# Epoch 19/90, Train Loss: 0.3494, Train Accuracy: 96.56%, Val Loss: 0.3642, Val Accuracy: 94.50%
# Epoch 20/90, Train Loss: 0.3463, Train Accuracy: 96.81%, Val Loss: 0.4093, Val Accuracy: 90.00%
# Epoch 21/90, Train Loss: 0.3476, Train Accuracy: 96.62%, Val Loss: 0.3672, Val Accuracy: 94.00%
# Epoch 22/90, Train Loss: 0.3473, Train Accuracy: 96.44%, Val Loss: 0.3752, Val Accuracy: 93.25%
# Epoch 23/90, Train Loss: 0.3470, Train Accuracy: 96.38%, Val Loss: 0.3778, Val Accuracy: 93.25%
# Epoch 24/90, Train Loss: 0.3517, Train Accuracy: 95.94%, Val Loss: 0.3705, Val Accuracy: 94.00%
# Epoch 25/90, Train Loss: 0.3506, Train Accuracy: 96.12%, Val Loss: 0.3584, Val Accuracy: 96.00%
# Epoch 26/90, Train Loss: 0.3471, Train Accuracy: 96.62%, Val Loss: 0.3866, Val Accuracy: 91.50%
# Epoch 27/90, Train Loss: 0.3427, Train Accuracy: 97.06%, Val Loss: 0.3741, Val Accuracy: 93.25%
# Epoch 28/90, Train Loss: 0.3393, Train Accuracy: 97.44%, Val Loss: 0.3600, Val Accuracy: 95.50%
# Epoch 29/90, Train Loss: 0.3397, Train Accuracy: 97.12%, Val Loss: 0.3699, Val Accuracy: 93.75%
# Epoch 30/90, Train Loss: 0.3433, Train Accuracy: 97.00%, Val Loss: 0.3687, Val Accuracy: 94.25%
# Epoch 31/90, Train Loss: 0.3367, Train Accuracy: 97.94%, Val Loss: 0.3667, Val Accuracy: 94.75%
# Epoch 32/90, Train Loss: 0.3415, Train Accuracy: 97.12%, Val Loss: 0.3796, Val Accuracy: 93.00%
# Epoch 33/90, Train Loss: 0.3431, Train Accuracy: 97.06%, Val Loss: 0.3847, Val Accuracy: 93.00%
# Epoch 34/90, Train Loss: 0.3436, Train Accuracy: 97.00%, Val Loss: 0.3709, Val Accuracy: 94.25%
# Epoch 35/90, Train Loss: 0.3425, Train Accuracy: 96.88%, Val Loss: 0.3771, Val Accuracy: 93.50%
# Epoch 36/90, Train Loss: 0.3392, Train Accuracy: 97.38%, Val Loss: 0.3706, Val Accuracy: 94.25%
# Epoch 37/90, Train Loss: 0.3404, Train Accuracy: 97.12%, Val Loss: 0.3740, Val Accuracy: 94.00%
# Epoch 38/90, Train Loss: 0.3380, Train Accuracy: 97.44%, Val Loss: 0.4155, Val Accuracy: 89.25%
# Epoch 39/90, Train Loss: 0.3418, Train Accuracy: 97.25%, Val Loss: 0.4032, Val Accuracy: 90.50%
# Epoch 40/90, Train Loss: 0.3455, Train Accuracy: 96.62%, Val Loss: 0.3681, Val Accuracy: 93.75%
# Epoch 41/90, Train Loss: 0.3437, Train Accuracy: 96.88%, Val Loss: 0.4060, Val Accuracy: 90.25%
# Epoch 42/90, Train Loss: 0.3436, Train Accuracy: 96.75%, Val Loss: 0.3699, Val Accuracy: 94.00%
# Epoch 43/90, Train Loss: 0.3417, Train Accuracy: 96.75%, Val Loss: 0.3677, Val Accuracy: 94.25%
# Epoch 44/90, Train Loss: 0.3419, Train Accuracy: 97.12%, Val Loss: 0.3590, Val Accuracy: 95.25%
# Epoch 45/90, Train Loss: 0.3393, Train Accuracy: 97.38%, Val Loss: 0.3775, Val Accuracy: 93.50%
# Epoch 46/90, Train Loss: 0.3386, Train Accuracy: 97.25%, Val Loss: 0.3672, Val Accuracy: 94.25%
# Epoch 47/90, Train Loss: 0.3360, Train Accuracy: 97.69%, Val Loss: 0.3630, Val Accuracy: 94.75%
# Epoch 48/90, Train Loss: 0.3392, Train Accuracy: 97.25%, Val Loss: 0.3633, Val Accuracy: 95.00%
# Epoch 49/90, Train Loss: 0.3377, Train Accuracy: 97.56%, Val Loss: 0.4009, Val Accuracy: 90.50%
# Epoch 50/90, Train Loss: 0.3373, Train Accuracy: 97.44%, Val Loss: 0.3714, Val Accuracy: 93.75%
# Epoch 51/90, Train Loss: 0.3336, Train Accuracy: 97.88%, Val Loss: 0.3704, Val Accuracy: 94.25%
# Epoch 52/90, Train Loss: 0.3308, Train Accuracy: 98.31%, Val Loss: 0.3674, Val Accuracy: 94.50%
# Epoch 53/90, Train Loss: 0.3364, Train Accuracy: 97.50%, Val Loss: 0.3870, Val Accuracy: 92.50%
# Epoch 54/90, Train Loss: 0.3410, Train Accuracy: 97.25%, Val Loss: 0.4085, Val Accuracy: 90.50%
# Epoch 55/90, Train Loss: 0.3313, Train Accuracy: 98.12%, Val Loss: 0.3702, Val Accuracy: 94.25%
# Epoch 56/90, Train Loss: 0.3388, Train Accuracy: 97.38%, Val Loss: 0.3649, Val Accuracy: 95.00%
# Epoch 57/90, Train Loss: 0.3374, Train Accuracy: 97.62%, Val Loss: 0.3844, Val Accuracy: 93.00%
# Epoch 58/90, Train Loss: 0.3322, Train Accuracy: 98.12%, Val Loss: 0.3701, Val Accuracy: 94.00%
# Epoch 59/90, Train Loss: 0.3320, Train Accuracy: 98.00%, Val Loss: 0.3837, Val Accuracy: 92.50%
# Epoch 60/90, Train Loss: 0.3344, Train Accuracy: 97.88%, Val Loss: 0.3768, Val Accuracy: 93.25%
# Epoch 61/90, Train Loss: 0.3342, Train Accuracy: 97.88%, Val Loss: 0.3693, Val Accuracy: 94.25%
# Epoch 62/90, Train Loss: 0.3321, Train Accuracy: 98.06%, Val Loss: 0.3882, Val Accuracy: 92.25%
# Epoch 63/90, Train Loss: 0.3396, Train Accuracy: 97.31%, Val Loss: 0.3755, Val Accuracy: 94.00%
# Epoch 64/90, Train Loss: 0.3395, Train Accuracy: 97.31%, Val Loss: 0.3870, Val Accuracy: 92.00%
# Epoch 65/90, Train Loss: 0.3334, Train Accuracy: 97.88%, Val Loss: 0.3609, Val Accuracy: 95.00%
# Epoch 66/90, Train Loss: 0.3347, Train Accuracy: 97.81%, Val Loss: 0.3678, Val Accuracy: 94.25%
# Epoch 67/90, Train Loss: 0.3277, Train Accuracy: 98.75%, Val Loss: 0.3849, Val Accuracy: 92.75%
# Epoch 68/90, Train Loss: 0.3390, Train Accuracy: 97.31%, Val Loss: 0.3567, Val Accuracy: 96.00%
# Epoch 69/90, Train Loss: 0.3312, Train Accuracy: 98.25%, Val Loss: 0.3606, Val Accuracy: 95.00%
# Epoch 70/90, Train Loss: 0.3349, Train Accuracy: 97.69%, Val Loss: 0.3676, Val Accuracy: 94.25%
# Epoch 71/90, Train Loss: 0.3431, Train Accuracy: 97.00%, Val Loss: 0.3712, Val Accuracy: 94.00%
# Epoch 72/90, Train Loss: 0.3330, Train Accuracy: 97.94%, Val Loss: 0.3859, Val Accuracy: 92.50%
# Epoch 73/90, Train Loss: 0.3299, Train Accuracy: 98.19%, Val Loss: 0.3575, Val Accuracy: 95.50%
# Epoch 74/90, Train Loss: 0.3252, Train Accuracy: 98.81%, Val Loss: 0.3749, Val Accuracy: 93.50%
# Epoch 75/90, Train Loss: 0.3377, Train Accuracy: 97.44%, Val Loss: 0.4207, Val Accuracy: 88.75%
# Epoch 76/90, Train Loss: 0.3290, Train Accuracy: 98.31%, Val Loss: 0.3669, Val Accuracy: 94.25%
# Epoch 77/90, Train Loss: 0.3299, Train Accuracy: 98.50%, Val Loss: 0.3604, Val Accuracy: 95.00%
# Epoch 78/90, Train Loss: 0.3245, Train Accuracy: 98.81%, Val Loss: 0.3637, Val Accuracy: 95.00%
# Epoch 79/90, Train Loss: 0.3295, Train Accuracy: 98.31%, Val Loss: 0.3707, Val Accuracy: 94.25%
# Epoch 80/90, Train Loss: 0.3238, Train Accuracy: 98.94%, Val Loss: 0.5591, Val Accuracy: 75.25%
# Epoch 81/90, Train Loss: 0.3324, Train Accuracy: 98.00%, Val Loss: 0.3730, Val Accuracy: 94.00%
# Epoch 82/90, Train Loss: 0.3315, Train Accuracy: 98.19%, Val Loss: 0.3724, Val Accuracy: 94.25%
# Epoch 83/90, Train Loss: 0.3332, Train Accuracy: 98.00%, Val Loss: 0.4144, Val Accuracy: 89.75%
# Epoch 84/90, Train Loss: 0.3279, Train Accuracy: 98.62%, Val Loss: 0.3658, Val Accuracy: 94.75%
# Epoch 85/90, Train Loss: 0.3280, Train Accuracy: 98.50%, Val Loss: 0.3828, Val Accuracy: 92.75%
# Epoch 86/90, Train Loss: 0.3274, Train Accuracy: 98.62%, Val Loss: 0.3654, Val Accuracy: 94.50%
# Epoch 87/90, Train Loss: 0.3280, Train Accuracy: 98.62%, Val Loss: 0.3540, Val Accuracy: 96.50%
# Epoch 88/90, Train Loss: 0.3303, Train Accuracy: 98.19%, Val Loss: 0.3778, Val Accuracy: 93.25%
# Epoch 89/90, Train Loss: 0.3266, Train Accuracy: 98.75%, Val Loss: 0.3825, Val Accuracy: 92.75%
# Epoch 90/90, Train Loss: 0.3247, Train Accuracy: 98.94%, Val Loss: 0.3880, Val Accuracy: 92.25%

# %% [markdown]
# ### Visualizing model performance

# %%
import matplotlib.pyplot as plt

fig, ax = plt.subplots(1, 2, figsize=(15, 5))

# Plotting training and validation accuracy
ax[0].plot(train_accuracies)
ax[0].plot(val_accuracies)
ax[0].set_title('Model Accuracy')
ax[0].set_xlabel('Epochs')
ax[0].set_ylabel('Accuracy')
ax[0].legend(['Train', 'Val'])

# Plotting training and validation loss
ax[1].plot(train_losses)
ax[1].plot(val_losses)
ax[1].set_title('Model Loss')
ax[1].set_xlabel('Epochs')
ax[1].set_ylabel('Loss')
ax[1].legend(['Train', 'Val'])

plt.show()

# %%
import csv
with open('CE neuron model.csv', 'w') as f:

    # using csv.writer method from CSV package
    write = csv.writer(f)
    write.writerow(['train accuracies'])
    write.writerow(train_accuracies)
    write.writerow(['validation accuracy'])
    write.writerow(val_accuracies)
    write.writerow(['train loss'])
    write.writerow(train_losses)
    write.writerow(['validation loss'])
    write.writerow(val_losses)
    write.writerow(outputs[:,1])
